# %%
import grdtiler

# %% [markdown]
# # Sentinel-1

# %%
safe = "/home/datawork-cersat-public/project/mpc-sentinel1/data/esa/sentinel-1b/L1/IW/S1B_IW_GRDH_1S/2021/305/S1B_IW_GRDH_1SDV_20211101T040706_20211101T040731_029389_0381E4_3CE3.SAFE"
_, tiles_t = grdtiler.tiling_prod(path=safe, tile_size={'line': 17600, 'sample': 17600},
                                resolution='400m', centering=True, side='left', detrend=True, 
                                noverlap=0, save=False,
                                config_file="config.yaml")
tiles_t
# Out:
# /scale/user/jrmiadan/conda_env/archive_env/lib/python3.11/site-packages/numpy/_core/numeric.py:442: RuntimeWarning: invalid value encountered in cast
#   multiarray.copyto(res, fill_value, casting='unsafe')
# Tiling: 100%|██████████| 9/9 [00:00<00:00, 39.29it/s]
# Adding footprints: 100%|██████████| 126/126 [00:00<00:00, 166.15it/s]
# <xarray.Dataset> Size: 19MB
# Dimensions:         (tile: 126, tile_line: 44, tile_sample: 44, pol: 2)
# Coordinates:
#     line            (tile, tile_line) float64 44kB 459.5 499.5 ... 1.626e+04
#     sample          (tile, tile_sample) float64 44kB 539.5 579.5 ... 2.514e+04
#   * pol             (pol) <U2 16B 'VV' 'VH'
#     spatial_ref     int64 8B 0
# Dimensions without coordinates: tile, tile_line, tile_sample
# Data variables:
#     ground_heading  (tile, tile_line, tile_sample) float32 976kB dask.array<chunksize=(1, 44, 44), meta=np.ndarray>
#     land_mask       (tile, tile_line, tile_sample) int8 244kB dask.array<chunksize=(1, 44, 44), meta=np.ndarray>
#     incidence       (tile, tile_line, tile_sample) float64 2MB dask.array<chunksize=(1, 44, 44), meta=np.ndarray>
#     longitude       (tile, tile_line, tile_sample) float64 2MB dask.array<chunksize=(1, 44, 44), meta=np.ndarray>
#     latitude        (tile, tile_line, tile_sample) float64 2MB dask.array<chunksize=(1, 44, 44), meta=np.ndarray>
#     nesz            (tile, pol, tile_line, tile_sample) float64 4MB dask.array<chunksize=(1, 1, 44, 44), meta=np.ndarray>
#     sigma0          (tile, pol, tile_line, tile_sample) float64 4MB dask.array<chunksize=(1, 1, 44, 44), meta=np.ndarray>
#     sigma0_detrend  (tile, pol, tile_line, tile_sample) float64 4MB dask.array<chunksize=(1, 1, 44, 44), meta=np.ndarray>
#     tile_footprint  (tile) <U204 103kB 'POLYGON ((30.26930249125278 36.831889...
#     lon_centroid    (tile) float64 1kB 30.15 29.96 29.77 ... 27.78 27.59 27.39
#     lat_centroid    (tile) float64 1kB 36.77 36.8 36.83 ... 35.8 35.83 35.86
# Attributes: (12/18)
#     name:              SENTINEL1_DS:/home/datawork-cersat-public/project/mpc-...
#     safe:              S1B_IW_GRDH_1SDV_20211101T040706_20211101T040731_02938...
#     swath:             IW
#     ipf_version:       3.31
#     platform:          SENTINEL-1B
#     start_date:        2021-11-01 04:07:06.878963
#     ...                ...
#     aux_ins:           S1B_AUX_INS_V20190514T090000_G20190513T071257.SAFE
#     tile_size:         17600m*17600m (line * sample)
#     resolution:        400m
#     polarizations:     VV VH
#     processing_level:  GRDH
#     main_footprint:    POLYGON ((30.34084017200427 36.8638179677022, 27.51190...

# %% [markdown]
# # RCM

# %%
safe = '/home/datawork-cersat-public/provider/csa/satellite/l1/rcm/rcm-2/sc50mc/2020/175/RCM2_OK2377166_PK2377288_1_SC50MC_20200623_220145_HH_HV_GRD'
_, tiles_t = grdtiler.tiling_prod(path=safe, tile_size={'line': 17600, 'sample': 17600},
                                        resolution='400m', centering=True, side='left',
                                        noverlap=0, save=False,
                                        config_file="config.yaml")
tiles_t
# Out:
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:213: UserWarning: no explicit representation of timezones available for np.datetime64
#   return data.astype(dtype, **kwargs)
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/safe_rcm/product/reader.py:58: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   {"timeStamp": ds["timeStamp"].astype("datetime64")}
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:213: UserWarning: no explicit representation of timezones available for np.datetime64
#   return data.astype(dtype, **kwargs)
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/safe_rcm/product/reader.py:67: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   {"timeStamp": ds["timeStamp"].astype("datetime64")}
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:213: UserWarning: no explicit representation of timezones available for np.datetime64
#   return data.astype(dtype, **kwargs)
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/safe_rcm/product/reader.py:58: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   {"timeStamp": ds["timeStamp"].astype("datetime64")}
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:213: UserWarning: no explicit representation of timezones available for np.datetime64
#   return data.astype(dtype, **kwargs)
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/safe_rcm/product/reader.py:67: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   {"timeStamp": ds["timeStamp"].astype("datetime64")}
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:213: UserWarning: no explicit representation of timezones available for np.datetime64
#   return data.astype(dtype, **kwargs)
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/safe_rcm/product/reader.py:58: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   {"timeStamp": ds["timeStamp"].astype("datetime64")}
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:213: UserWarning: no explicit representation of timezones available for np.datetime64
#   return data.astype(dtype, **kwargs)
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/safe_rcm/product/reader.py:67: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   {"timeStamp": ds["timeStamp"].astype("datetime64")}
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:213: UserWarning: no explicit representation of timezones available for np.datetime64
#   return data.astype(dtype, **kwargs)
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/safe_rcm/product/reader.py:58: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   {"timeStamp": ds["timeStamp"].astype("datetime64")}
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:213: UserWarning: no explicit representation of timezones available for np.datetime64
#   return data.astype(dtype, **kwargs)
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/safe_rcm/product/reader.py:67: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   {"timeStamp": ds["timeStamp"].astype("datetime64")}
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:213: UserWarning: no explicit representation of timezones available for np.datetime64
#   return data.astype(dtype, **kwargs)
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/safe_rcm/product/reader.py:58: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   {"timeStamp": ds["timeStamp"].astype("datetime64")}
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:213: UserWarning: no explicit representation of timezones available for np.datetime64
#   return data.astype(dtype, **kwargs)
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/safe_rcm/product/reader.py:67: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   {"timeStamp": ds["timeStamp"].astype("datetime64")}
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:213: UserWarning: no explicit representation of timezones available for np.datetime64
#   return data.astype(dtype, **kwargs)
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/safe_rcm/product/reader.py:58: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   {"timeStamp": ds["timeStamp"].astype("datetime64")}
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:213: UserWarning: no explicit representation of timezones available for np.datetime64
#   return data.astype(dtype, **kwargs)
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/safe_rcm/product/reader.py:67: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   {"timeStamp": ds["timeStamp"].astype("datetime64")}
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:213: UserWarning: no explicit representation of timezones available for np.datetime64
#   return data.astype(dtype, **kwargs)
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/safe_rcm/product/reader.py:58: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   {"timeStamp": ds["timeStamp"].astype("datetime64")}
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:213: UserWarning: no explicit representation of timezones available for np.datetime64
#   return data.astype(dtype, **kwargs)
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/safe_rcm/product/reader.py:67: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   {"timeStamp": ds["timeStamp"].astype("datetime64")}
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:213: UserWarning: no explicit representation of timezones available for np.datetime64
#   return data.astype(dtype, **kwargs)
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/safe_rcm/product/reader.py:58: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   {"timeStamp": ds["timeStamp"].astype("datetime64")}
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:213: UserWarning: no explicit representation of timezones available for np.datetime64
#   return data.astype(dtype, **kwargs)
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/safe_rcm/product/reader.py:67: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   {"timeStamp": ds["timeStamp"].astype("datetime64")}
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:213: UserWarning: no explicit representation of timezones available for np.datetime64
#   return data.astype(dtype, **kwargs)
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/safe_rcm/product/reader.py:58: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   {"timeStamp": ds["timeStamp"].astype("datetime64")}
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:213: UserWarning: no explicit representation of timezones available for np.datetime64
#   return data.astype(dtype, **kwargs)
# /home1/datawork/jrmiadan/micromamba/envs/envs/archive_verif/lib/python3.11/site-packages/safe_rcm/product/reader.py:67: UserWarning: Converting non-nanosecond precision datetime values to nanosecond precision. This behavior can eventually be relaxed in xarray, as it is an artifact from pandas which is now beginning to support non-nanosecond precision values. This warning is caused by passing non-nanosecond np.datetime64 or np.timedelta64 values to the DataArray or Variable constructor; it can be silenced by converting the values to nanosecond precision ahead of time.
#   {"timeStamp": ds["timeStamp"].astype("datetime64")}
# DEBUG:xsarsea.windspeed.models:path model : /home/datawork-cersat-public/cache/project/sarwing/GMFS/nc_luts/nc_lut_gmf_cmod7_Rhigh_hh_mouche1.nc
# DEBUG:xsarsea.windspeed.models:name model : nc_lut_gmf_cmod7_Rhigh_hh_mouche1
# DEBUG:xsarsea.windspeed.models:register model nc_lut_gmf_cmod7_Rhigh_hh_mouche1 pol=HH units=linear
#  inc_range=[np.float64(16.0), np.float64(66.0)] wspd_range=[np.float64(0.2), np.float64(50.0)] phi_range=[np.float64(0.0), np.float64(180.0)]
#  inc_step=0.1 wspd_step=0.1 phi_step=1.0
#  inc_step_lr=1.0 wspd_step_lr=0.2 phi_step_lr=2.5
# DEBUG:xsarsea.windspeed.models:path model : /home/datawork-cersat-public/cache/project/sarwing/GMFS/nc_luts/nc_lut_gmf_cmod7_Rhigh_hh_zhangB.nc
# DEBUG:xsarsea.windspeed.models:name model : nc_lut_gmf_cmod7_Rhigh_hh_zhangB
# DEBUG:xsarsea.windspeed.models:register model nc_lut_gmf_cmod7_Rhigh_hh_zhangB pol=HH units=linear
#  inc_range=[np.float64(16.0), np.float64(66.0)] wspd_range=[np.float64(0.2), np.float64(50.0)] phi_range=[np.float64(0.0), np.float64(180.0)]
#  inc_step=0.1 wspd_step=0.1 phi_step=1.0
#  inc_step_lr=1.0 wspd_step_lr=0.2 phi_step_lr=2.5
# DEBUG:xsarsea.windspeed.models:path model : /home/datawork-cersat-public/cache/project/sarwing/GMFS/nc_luts/nc_lut_gmf_cmod5n_Rhigh_hh_zhangB.nc
# DEBUG:xsarsea.windspeed.models:name model : nc_lut_gmf_cmod5n_Rhigh_hh_zhangB
# DEBUG:xsarsea.windspeed.models:register model nc_lut_gmf_cmod5n_Rhigh_hh_zhangB pol=HH units=linear
#  inc_range=[np.float64(17.0), np.float64(50.0)] wspd_range=[np.float64(0.2), np.float64(50.0)] phi_range=[np.float64(0.0), np.float64(180.0)]
#  inc_step=0.1 wspd_step=0.1 phi_step=1.0
#  inc_step_lr=1.0 wspd_step_lr=0.2 phi_step_lr=2.5
# DEBUG:xsarsea.windspeed.models:path model : /home/datawork-cersat-public/cache/project/sarwing/GMFS/nc_luts/nc_lut_gmf_cmod5n_Rhigh_hh_mouche1.nc
# DEBUG:xsarsea.windspeed.models:name model : nc_lut_gmf_cmod5n_Rhigh_hh_mouche1
# DEBUG:xsarsea.windspeed.models:register model nc_lut_gmf_cmod5n_Rhigh_hh_mouche1 pol=HH units=linear
#  inc_range=[np.float64(17.0), np.float64(50.0)] wspd_range=[np.float64(0.2), np.float64(50.0)] phi_range=[np.float64(0.0), np.float64(180.0)]
#  inc_step=0.1 wspd_step=0.1 phi_step=1.0
#  inc_step_lr=1.0 wspd_step_lr=0.2 phi_step_lr=2.5
# DEBUG:xsarsea.windspeed.models:path model : /home/datawork-cersat-public/cache/project/sarwing/GMFS/nc_luts/nc_lut_gmf_cmod7_Rlow_hh_zhangB.nc
# DEBUG:xsarsea.windspeed.models:name model : nc_lut_gmf_cmod7_Rlow_hh_zhangB
# DEBUG:xsarsea.windspeed.models:register model nc_lut_gmf_cmod7_Rlow_hh_zhangB pol=HH units=linear
#  inc_range=[np.float64(16.0), np.float64(66.0)] wspd_range=[np.float64(0.2), np.float64(50.0)] phi_range=[np.float64(0.0), np.float64(180.0)]
#  inc_step=0.1 wspd_step=0.1 phi_step=1.0
#  inc_step_lr=1 wspd_step_lr=0.2 phi_step_lr=2.5
# DEBUG:xsarsea.windspeed.models:path model : /home/datawork-cersat-public/cache/project/sarwing/GMFS/nc_luts/nc_lut_gmf_cmod5n_Rhigh_hh_zhangA.nc
# DEBUG:xsarsea.windspeed.models:name model : nc_lut_gmf_cmod5n_Rhigh_hh_zhangA
# DEBUG:xsarsea.windspeed.models:register model nc_lut_gmf_cmod5n_Rhigh_hh_zhangA pol=HH units=linear
#  inc_range=[np.float64(17.0), np.float64(50.0)] wspd_range=[np.float64(0.2), np.float64(50.0)] phi_range=[np.float64(0.0), np.float64(180.0)]
#  inc_step=0.1 wspd_step=0.1 phi_step=1.0
#  inc_step_lr=1.0 wspd_step_lr=0.2 phi_step_lr=2.5
# DEBUG:xsarsea.windspeed.models:path model : /home/datawork-cersat-public/cache/project/sarwing/GMFS/nc_luts/nc_lut_gmf_cmod5n_Rlow_hh_zhangA.nc
# DEBUG:xsarsea.windspeed.models:name model : nc_lut_gmf_cmod5n_Rlow_hh_zhangA
# DEBUG:xsarsea.windspeed.models:register model nc_lut_gmf_cmod5n_Rlow_hh_zhangA pol=HH units=linear
#  inc_range=[np.float64(17.0), np.float64(50.0)] wspd_range=[np.float64(0.2), np.float64(50.0)] phi_range=[np.float64(0.0), np.float64(180.0)]
#  inc_step=0.1 wspd_step=0.1 phi_step=1.0
#  inc_step_lr=1.0 wspd_step_lr=0.2 phi_step_lr=2.5
# DEBUG:xsarsea.windspeed.models:path model : /home/datawork-cersat-public/cache/project/sarwing/GMFS/nc_luts/nc_lut_gmf_cmod7_Rlow_hh_zhangA.nc
# DEBUG:xsarsea.windspeed.models:name model : nc_lut_gmf_cmod7_Rlow_hh_zhangA
# DEBUG:xsarsea.windspeed.models:register model nc_lut_gmf_cmod7_Rlow_hh_zhangA pol=HH units=linear
#  inc_range=[np.float64(16.0), np.float64(66.0)] wspd_range=[np.float64(0.2), np.float64(50.0)] phi_range=[np.float64(0.0), np.float64(180.0)]
#  inc_step=0.1 wspd_step=0.1 phi_step=1.0
#  inc_step_lr=1 wspd_step_lr=0.2 phi_step_lr=2.5
# DEBUG:xsarsea.windspeed.models:path model : /home/datawork-cersat-public/cache/project/sarwing/GMFS/nc_luts/nc_lut_gmf_cmod7_Rlow_hh_mouche1.nc
# DEBUG:xsarsea.windspeed.models:name model : nc_lut_gmf_cmod7_Rlow_hh_mouche1
# DEBUG:xsarsea.windspeed.models:register model nc_lut_gmf_cmod7_Rlow_hh_mouche1 pol=HH units=linear
#  inc_range=[np.float64(16.0), np.float64(66.0)] wspd_range=[np.float64(0.2), np.float64(50.0)] phi_range=[np.float64(0.0), np.float64(180.0)]
#  inc_step=0.1 wspd_step=0.1 phi_step=1.0
#  inc_step_lr=1 wspd_step_lr=0.2 phi_step_lr=2.5
# DEBUG:xsarsea.windspeed.models:path model : /home/datawork-cersat-public/cache/project/sarwing/GMFS/nc_luts/nc_lut_cmodms1ahw.nc
# DEBUG:xsarsea.windspeed.models:no phi_range attribute for model : nc_lut_cmodms1ahw
# DEBUG:xsarsea.windspeed.models:no phi_step attribute for model : nc_lut_cmodms1ahw
# DEBUG:xsarsea.windspeed.models:name model : nc_lut_cmodms1ahw
# DEBUG:xsarsea.windspeed.models:register model nc_lut_cmodms1ahw pol=VH units=dB
#  inc_range=[np.float64(17.0), np.float64(50.0)] wspd_range=[np.float64(3.0), np.float64(80.0)] phi_range=None
#  inc_step=0.1 wspd_step=0.1 phi_step=1.0
#  inc_step_lr=1.0 wspd_step_lr=0.2 phi_step_lr=2.5
# DEBUG:xsarsea.windspeed.models:path model : /home/datawork-cersat-public/cache/project/sarwing/GMFS/nc_luts/nc_lut_gmf_cmod5n_Rlow_hh_zhangB.nc
# DEBUG:xsarsea.windspeed.models:name model : nc_lut_gmf_cmod5n_Rlow_hh_zhangB
# DEBUG:xsarsea.windspeed.models:register model nc_lut_gmf_cmod5n_Rlow_hh_zhangB pol=HH units=linear
#  inc_range=[np.float64(17.0), np.float64(50.0)] wspd_range=[np.float64(0.2), np.float64(50.0)] phi_range=[np.float64(0.0), np.float64(180.0)]
#  inc_step=0.1 wspd_step=0.1 phi_step=1.0
#  inc_step_lr=1.0 wspd_step_lr=0.2 phi_step_lr=2.5
# DEBUG:xsarsea.windspeed.models:path model : /home/datawork-cersat-public/cache/project/sarwing/GMFS/nc_luts/nc_lut_gmf_cmod5n_Rlow_hh_mouche1.nc
# DEBUG:xsarsea.windspeed.models:name model : nc_lut_gmf_cmod5n_Rlow_hh_mouche1
# DEBUG:xsarsea.windspeed.models:register model nc_lut_gmf_cmod5n_Rlow_hh_mouche1 pol=HH units=linear
#  inc_range=[np.float64(17.0), np.float64(50.0)] wspd_range=[np.float64(0.2), np.float64(50.0)] phi_range=[np.float64(0.0), np.float64(180.0)]
#  inc_step=0.1 wspd_step=0.1 phi_step=1.0
#  inc_step_lr=1.0 wspd_step_lr=0.2 phi_step_lr=2.5
# DEBUG:xsarsea.windspeed.models:path model : /home/datawork-cersat-public/cache/project/sarwing/GMFS/nc_luts/nc_lut_gmf_cmod7_Rhigh_hh_zhangA.nc
# DEBUG:xsarsea.windspeed.models:name model : nc_lut_gmf_cmod7_Rhigh_hh_zhangA
# DEBUG:xsarsea.windspeed.models:register model nc_lut_gmf_cmod7_Rhigh_hh_zhangA pol=HH units=linear
#  inc_range=[np.float64(16.0), np.float64(66.0)] wspd_range=[np.float64(0.2), np.float64(50.0)] phi_range=[np.float64(0.0), np.float64(180.0)]
#  inc_step=0.1 wspd_step=0.1 phi_step=1.0
#  inc_step_lr=1.0 wspd_step_lr=0.2 phi_step_lr=2.5
# DEBUG:xsarsea.windspeed.models:lut_resolution nc_lut_gmf_cmod7_Rhigh_hh_zhangA from _raw_lut : high
# DEBUG:xsarsea.windspeed.models:desired nc_lut_gmf_cmod7_Rhigh_hh_zhangA resolution : high
# DEBUG:xsarsea.windspeed.models:lut nc_lut_gmf_cmod7_Rhigh_hh_zhangA already at desired resolution high with exact same params : no interpolation needed
# Tiling: 100%|██████████| 16/16 [00:00<00:00, 22.58it/s]
# Adding footprints: 100%|██████████| 320/320 [00:00<00:00, 1548.26it/s]
# <xarray.Dataset> Size: 41MB
# Dimensions:         (tile: 320, pol: 2, tile_line: 44, tile_sample: 44)
# Coordinates:
#     sample          (tile, tile_sample) float64 113kB 189.5 209.5 ... 1.777e+04
#   * pol             (pol) <U2 16B 'HH' 'HV'
#     line            (tile, tile_line) float64 113kB 329.5 349.5 ... 1.439e+04
# Dimensions without coordinates: tile, tile_line, tile_sample
# Data variables:
#     nesz            (tile, pol, tile_line, tile_sample) float32 5MB dask.array<chunksize=(1, 1, 44, 44), meta=np.ndarray>
#     sigma0          (tile, pol, tile_line, tile_sample) float64 10MB dask.array<chunksize=(1, 1, 44, 44), meta=np.ndarray>
#     land_mask       (tile, tile_line, tile_sample) int8 620kB dask.array<chunksize=(1, 44, 44), meta=np.ndarray>
#     ground_heading  (tile, tile_line, tile_sample) float32 2MB dask.array<chunksize=(1, 44, 44), meta=np.ndarray>
#     latitude        (tile, tile_line, tile_sample) float64 5MB dask.array<chunksize=(1, 44, 44), meta=np.ndarray>
#     longitude       (tile, tile_line, tile_sample) float64 5MB dask.array<chunksize=(1, 44, 44), meta=np.ndarray>
#     incidence       (tile, tile_line, tile_sample) float32 2MB dask.array<chunksize=(1, 44, 44), meta=np.ndarray>
#     sigma0_detrend  (tile, pol, tile_line, tile_sample) float64 10MB dask.array<chunksize=(1, 1, 44, 44), meta=np.ndarray>
#     tile_footprint  (tile) <U209 268kB 'POLYGON ((-62.240588787740215 38.1285...
#     lon_centroid    (tile) float64 3kB -62.16 -61.96 -61.77 ... -59.01 -58.8
#     lat_centroid    (tile) float64 3kB 38.22 38.25 38.27 ... 41.0 41.02 41.04
# Attributes: (12/18)
#     safe:                         RCM2_OK2377166_PK2377288_1_SC50MC_20200623_...
#     swath:                        SC50MC
#     copyright:                    RCM Data and Products (c) CSA, 2020 - All R...
#     productId:                    2377288_1
#     documentIdentifier:           RCM-SP-53-0419, Issue 2/9
#     securityClassification:       Non classifié / Unclassified
#     ...                           ...
#     pixel_sample_m:               20.0
#     tile_size:                    17600m*17600m (line * sample)
#     resolution:                   400m
#     polarizations:                HH HV
#     processing_level:             GRD
#     main_footprint:               POLYGON ((-62.26944052740825 38.06372507587...

# %% [markdown]
# # RS2

# %%
safe = '/home/datawork-cersat-public/cache/project/sarwing/data/RS2/L1/VV_VH/2015/245/RS2_OK99999_PK999999_DK999999_XXXX_20150902_201620_VV_VH_SGF'
_, tiles_t = grdtiler.tiling_prod(path=safe, tile_size={'line': 17600, 'sample': 17600},
                                        resolution='400m', centering=True, side='left',
                                         noverlap=0, save=False)
tiles_t
# Out:
# /home1/datawork/jrmiadan/micromamba/envs/grdtiler_env/lib/python3.11/site-packages/dask/_task_spec.py:745: RuntimeWarning: invalid value encountered in divide
#   return self.func(*new_argspec)
# Tiling: 100%|██████████| 28/28 [00:02<00:00, 14.00it/s]
# Adding footprints: 100%|██████████| 812/812 [00:17<00:00, 45.61it/s]
# <xarray.Dataset> Size: 110MB
# Dimensions:         (tile: 812, pol: 2, tile_line: 44, tile_sample: 44)
# Coordinates:
#     sample          (tile, tile_sample) float64 286kB 131.5 139.5 ... 1.033e+04
#   * pol             (pol) <U2 16B 'VV' 'VH'
#     line            (tile, tile_line) float64 286kB 131.5 139.5 ... 9.98e+03
# Dimensions without coordinates: tile, tile_line, tile_sample
# Data variables:
#     nesz            (tile, pol, tile_line, tile_sample) float32 13MB dask.array<chunksize=(1, 1, 44, 44), meta=np.ndarray>
#     sigma0          (tile, pol, tile_line, tile_sample) float64 25MB dask.array<chunksize=(1, 1, 44, 44), meta=np.ndarray>
#     land_mask       (tile, tile_line, tile_sample) int8 2MB dask.array<chunksize=(1, 44, 44), meta=np.ndarray>
#     ground_heading  (tile, tile_line, tile_sample) float32 6MB dask.array<chunksize=(1, 44, 44), meta=np.ndarray>
#     latitude        (tile, tile_line, tile_sample) float64 13MB dask.array<chunksize=(1, 44, 44), meta=np.ndarray>
#     longitude       (tile, tile_line, tile_sample) float64 13MB dask.array<chunksize=(1, 44, 44), meta=np.ndarray>
#     incidence       (tile, tile_line, tile_sample) float64 13MB dask.array<chunksize=(1, 44, 44), meta=np.ndarray>
#     sigma0_detrend  (tile, pol, tile_line, tile_sample) float64 25MB dask.array<chunksize=(1, 1, 44, 44), meta=np.ndarray>
#     tile_footprint  (tile) <U210 682kB 'POLYGON ((-34.12053711531161 17.75673...
#     lon_centroid    (tile) float64 6kB -34.06 -33.9 -33.73 ... -30.48 -30.31
#     lat_centroid    (tile) float64 6kB 17.85 17.88 17.92 ... 22.87 22.89 22.92
# Attributes: (12/17)
#     satellite:              RADARSAT-2
#     inputDatasetId:         /Fred/RSAT-2/454152G
#     satelliteHeight_units:  m
#     satelliteHeight:        794036.9188864924
#     passDirection:          Ascending
#     swath:                  XXXX
#     ...                     ...
#     tile_size:              17600m*17600m (line * sample)
#     resolution:             400m
#     polarizations:          VH VV
#     processing_level:       SGF
#     main_footprint:         POLYGON ((-34.16812595197435 17.68596515510246, -...
#     safe:                   RS2_OK99999_PK999999_DK999999_XXXX_20150902_20162...
